# %%
num1=6
num2=7
res=(num1+num2)
print(res,end=';')
print(num1)
# Out:
# 13;6

# %%
num1 = int(input("Enter any number"))
num2 = int(input("Enter any number"))
res= num1+num2
print(res)
# Out:
# Enter any number 7
# Enter any number 9
# 16

# %%
5+5.7+False
# Out:
# 10.7

# %%
num1 = int(input("Enter any number"))
num2 = int(input("Enter any number"))
res= num1-num2
print(res)
# Out:
# Enter any number 9
# Enter any number 7
# 2

# %%
n1=int(input("Enter any number"))
n1
# Out:
# Enter any number 8
# 8

# %%
num1 = int(input("Enter any number"))
num2 = int(input("Enter any number"))
res= num1*num2
print(res)
# Out:
# Enter any number 8
# Enter any number 9
# 72

# %%
num1 = int(input("Enter any number"))
num2 = int(input("Enter any number"))
res= num1%num2
print(res)
# Out:
# Enter any number 6
# Enter any number 5
# 1

# %%
num1 = int(input("Enter any number"))
num2 = int(input("Enter any number"))
res= num1//num2
print(res)
# Out:
# Enter any number 9
# Enter any number 8
# 1

# %%
num1 = int(input("Enter any number"))
num2 = int(input("Enter any number"))
res= num1/num2
print(res)
# Out:
# Enter any number 9
# Enter any number 8
# 1.125

# %%
num1 = int(input("Enter any number"))
num2 = int(input("Enter any number"))
res= num1**num2
print(res)
# Out:
# Enter any number 9
# Enter any number 8
# 43046721

# %%
#write a program to perform area of circle where radius is user input
rad=float(input("enter radius of circle"))
cir_area= 3.14*rad*rad
print(" radius of circle: ",cir_area)
# Out:
# enter radius of circle 8
#  radius of circle:  200.96

# %%
#write area of triangle
base= float(input("enter base"))
height=float(input("enter height"))
tri_area=base*height
print(" area of triangle :", tri_area)
# Out:
# enter base 8
# enter height 9
#  area of triangle : 72.0

# %%
#write area of square 
side = float(input("enter side"))
sqr_area= side*side
print(" area of square :", sqr_area)
# Out:
# enter side 8
#  area of square : 64.0

# %%
#write area of rectangle
length = float(input("enter length"))
breadth = float(input("enter breadth"))
rec_area= length*breadth
print("area of rectangle :", rec_area)
# Out:
# enter length 5
# enter breadth 6
# area of rectangle : 30.0

# %%
num1= int(input("enter a number:"))
num2= int(input("enter a number:"))
if (num1>num2):
    print("num1 is greater")
    print("if block")
elif(num1<num2):
    print("num2 is greater")
    print("elif block")
else:
    print("both numbers are equal")
    print("end")
# Out:
# enter a number: 3
# enter a number: 4
# num2 is greater
# elif block

# %%
#wap given number is positive or negative
num = int(input ("enter a number:"))
if num>0:
    print("num is positive")
elif num<0:
    print("num is negative")
else:
    print("num is zero")
# Out:
# enter a number: 5
# num is positive

# %%
#wap to check given number iseven or odd
num= int(input("enter a number:"))
if num%2 == 0:
    print("num is even")
else:
    print("num is odd")
# Out:
# enter a number: 7
# num is odd
